# %%
p = "codegnan"
print(p)
# Out:
# codegnan

# %%
## string operations

#concatination
p1 ="code"
p2 = "gnan"
p3 = p1+" "+ p2
print(p3)
print(p1+p1+p1+p1+p2+p2+p2+p2)
print(p3*3)
# Out:
# code gnan
# codecodecodecodegnangnangnangnan
# code gnancode gnancode gnan

# %%
s = "sammaiah"
print(s)
print(s[0])
print("k" + s[1:]) #sammaiah to kammaiah
# Out:
# sammaiah
# s
# kammaiah

# %%
j = "phanindra"
print(j[0])
x = "r" + j[1:]
print(x,j)
# Out:
# p
# rhanindra phanindra

# %%
a = "phani"+"143"
print(a)
# Out:
# phani143

# %%
#string functions
## case conversion-functions-lower(),upper(),title(),swapcase(),capitalize()
s = "I Am a python batch stuDent"
print(len(s))
print(s.lower())
print(s.upper())
print(s.swapcase())
print(s.capitalize())
print(s.title())
# Out:
# 27
# i am a python batch student
# I AM A PYTHON BATCH STUDENT
# i aM A PYTHON BATCH STUdENT
# I am a python batch student
# I Am A Python Batch Student

# %%
#sub string index finding
#find
j = "I Am a python batch student"
print(j.find("t"))
print(j.find("t",10))
print(s.find("z"))
print(s.index("t"))
# Out:
# 9
# 16
# -1
# 9

# %%
##strip()-it removes the white spaces
t = "             phanindar      kumar            "
print(t)
print(t.strip())
print(t.lstrip())#left strip
print(t.rstrip())#right strip
# Out:
#              phanindar      kumar
# phanindar      kumar
# phanindar      kumar
#              phanindar      kumar

# %%
t = "@@@@@@@@@@@@@ph@nindr@ kum@r@@@@@@@@@@@"
print(t)
print(t.strip("@"))
print(t.rstrip("@"))
print(t.lstrip())
# Out:
# @@@@@@@@@@@@@ph@nindr@ kum@r@@@@@@@@@@@
# ph@nindr@ kum@r
# @@@@@@@@@@@@@ph@nindr@ kum@r
# @@@@@@@@@@@@@ph@nindr@ kum@r@@@@@@@@@@@

# %%
#case checking functions
p1 = "code"
p2 = "gnan"
p3 = "123"
p4 = "abc123"
p5 = "codegnan"
print(p1.isupper())
print(p2.islower())
print(p1.islower())
print(p2.isupper())
print(p3.isdigit())
print(p4.isalpha())
print(p4.isalnum())
print(p4.isdigit())
print(p5.isalpha())
# Out:
# False
# True
# True
# False
# True
# False
# True
# False
# True

# %%
# user name and password validation using case check functions
##username
username=input("enter the username:")
if len(username) >=8 and username[0].isalpha() :
    for char in username:
        if char.isupper():
            has_upper=True
        elif char.islower():
            has_lower=True
        elif char.isdigit():
            has_digit=True
        elif char in ["_","@"]:
            has_special=True
    if has_upper and has_lower and has_digit and has_special:
        print("username is valid!")
    else:
        print("username is invalid!")
else:
    print("username is not valid!")
# Out:
# enter the username Phani@123
# username is valid!

# %%
## password
password =input("neter the password:")
if len(password) >=8 and password[0].isalpha():
    for char in password:
        if char.isupper():
            has_upper=True
        elif char.islower():
            has_lower=True
        elif char.isdigit():
            has_digit=True
        elif char in ["_","@"]:
            has_special=True
    if has_upper and has_lower and has_digit and has_special:
        print("password is valid!")
    else:
        print("password is invalid!")
else:
    print("password is not valid!")
# Out:
# neter the password: Phani@1432
# password is valid!
