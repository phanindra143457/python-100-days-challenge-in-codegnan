# %%
#### Input reading from user and type conversion\

- int : string,float
- Float : string,integer
- String : integer,Float,list;tuple
- list : string .tuple ,dictionary
- tuple : string,list
- basic problems on data types and type conversions
# Out:
#   Cell In[1], line 3
#     - int : string,float
#     ^
# SyntaxError: illegal target for annotation

# %%
## integet to another data type conversion

num = int(input())
float_num = float(num)
print(type(float_num),float_num)      ## ->int to float
str_num=str(num)                      
print(type(str_num),str_num)  ## ->int to string
# Out:
#  13
# <class 'float'> 13.0
# <class 'str'> 13

# %%
## float reading from user

val = float(input())
print(type(val),val)
# Out:
#  10.25
# <class 'float'> 10.25

# %%
### float to int and string
val = float(input())
num =int(val)
print(type(num),num)
num=str(val)
print(type(num),num)
# Out:
#  10.2225
# <class 'int'> 10
# <class 'str'> 10.2225

# %%
## reading string from user
string=str(input())
print(type(string),string)
# Out:
#  phanindra
# <class 'str'> phanindra

# %%
### string to int ,float,list,set and tuple
s=input()
val=float(s)
print(type(val),val)
num=int(s)
print(type(num),num)
# Out:
#  10
# <class 'float'> 10.0
# <class 'int'> 10

# %%
s = input()
list_str =list(s)
print(type(list_str),list_str)
tuple_str =tuple(s)
print(type(tuple_str),tuple_str)
set_str =set(s)
print(type(set_str),set_str)
# Out:
#  phanindra
# <class 'list'> ['p', 'h', 'a', 'n', 'i', 'n', 'd', 'r', 'a']
# <class 'tuple'> ('p', 'h', 'a', 'n', 'i', 'n', 'd', 'r', 'a')
# <class 'set'> {'d', 'i', 'h', 'p', 'n', 'r', 'a'}

# %%
## reading list of integers from user

l = list(map(int,input().split()))
print(l)
# Out:
#  12 13 15 30
# [12, 13, 15, 30]

# %%
l = list(map(int,input().split()))
print(l)
# Out:
#  1234567890
# [1234567890]

# %%
l = list(map(str,input().split()))
print(l)
# Out:
#  hii 12 15 30 hello
# ['hii', '12', '15', '30', 'hello']

# %%
### list to string ,tuple,set
l = [1,2,3,'hlo friend','hii',3.56]
str_list=str(l)
tuple_list=tuple(l)
set_list=set(l)
print(type(str_list),str_list)
print(type(tuple_list),tuple_list)
print(type(set_list),set_list)
# Out:
# <class 'str'> [1, 2, 3, 'hlo friend', 'hii', 3.56]
# <class 'tuple'> (1, 2, 3, 'hlo friend', 'hii', 3.56)
# <class 'set'> {1, 2, 3, 'hlo friend', 3.56, 'hii'}

# %%
## list to dictionary
l = [(1,1),(2,'j'),(3,'k'),('hello','world')]
print(dict(l))
# Out:
# {1: 1, 2: 'j', 3: 'k', 'hello': 'world'}

# %%
### read tuple of integers from user
### read list of integers from user

t = tuple(map(int,input().split()))
print(t)
# Out:
#  123 234 345
# (123, 234, 345)

# %%
### tuple to list ,set and string
t = (1,2,3,'hii friend','hello')
print(list(t))
print(set(t))
print(str(t))
# Out:
# [1, 2, 3, 'hii friend', 'hello']
# {1, 2, 3, 'hello', 'hii friend'}
# (1, 2, 3, 'hii friend', 'hello')

# %%
### string to list ,set and tuple
str = (1,2,3,'hii friend','hello')
print(list(str))
print(set(str))
print(tuple(str))
# Out:
# [1, 2, 3, 'hii friend', 'hello']
# {1, 2, 3, 'hello', 'hii friend'}
# (1, 2, 3, 'hii friend', 'hello')

# %%
### set to list ,tuple and string
s = {1,2,3,'hii friend','hello'}
print(list(s))
print(tuple(s))
print(str(s))
# Out:
# [1, 2, 3, 'hello', 'hii friend']
# (1, 2, 3, 'hello', 'hii friend')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       3 print(list(s))
#       4 print(tuple(s))
# ----> 5 print(str(s))
#
# TypeError: 'tuple' object is not callable

# %%
num = eval(input())
print(type(num),num)
# Out:
#  [1,2,3,4]
# <class 'list'> [1, 2, 3, 4]

# %%
num = eval(input())
print(type(num),num)
# Out:
#  1,2,3,4
# <class 'tuple'> (1, 2, 3, 4)

# %%
num = eval(input())
print(type(num),num)
# Out:
#  {'a':1,'b':2}
# <class 'dict'> {'a': 1, 'b': 2}

# %%
num = eval(input())
print(type(num),num)
# Out:
#  1,2,3,4
# <class 'tuple'> (1, 2, 3, 4)

# %%
d = {'a':2,'b':6}
print(list(d))
# Out:
# ['a', 'b']
