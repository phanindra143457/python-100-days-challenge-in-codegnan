# %%
#strings

s = "sankranthi"
print(s[1:5:2]) #[start:end:step]
print(s[::1])
print(s[3:9:1])
print(s[7:])
print(s[:7])
print(s[:])
# Out:
# ak
# sankranthi
# kranth
# thi
# sankran
# sankranthi

# %%
p = "jagannadham"

print(p[2:7:1])
print(p[1:1])
print(p[::1])
print(p[:9])
print(p[5:])
print(p[0])
print(p[-1:5:-1])
# Out:
# ganna
#
# jagannadham
# jagannadh
# nadham
# j
# mahda
