# %%
##Dictionaries

details={'name':'phanindra','age':23,'area':'manuguru'}
print(type(details))
# Out:
# <class 'dict'>

# %%
details={'name':'phanindra','age':23,'area':'manuguru'}
print(details['name'])
print(details['area'])
# Out:
# phanindra
# manuguru

# %%
details={'name':'phanindra','age':23,'area':'manuguru'}
print(details['Name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 details={'name':'phanindra','age':23,'area':'manuguru'}
# ----> 2 print(details['Name'])
#
# KeyError: 'Name'

# %%
## updating values and items
details={'name':'phanindra','age':23,'area':'manuguru'}
details['name']='kumar'
print(details)
details['area']='venkatpathi nagar'
print(details)
details['course']
# Out:
# {'name': 'kumar', 'age': 23, 'area': 'manuguru'}
# {'name': 'kumar', 'age': 23, 'area': 'venkatpathi nagar'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 7
#       5 details['area']='venkatpathi nagar'
#       6 print(details)
# ----> 7 details['course']
#
# KeyError: 'course'

# %%
##assigning new value into the dictionary
details={'name':'phanindra','age':23,'area':'manuguru'}
details['course']='python'
print(details)
# Out:
# {'name': 'phanindra', 'age': 23, 'area': 'manuguru', 'course': 'python'}

# %%
## dictionary functions
##accessing values
##get (key,default_value):it returns value if key is present in dictionaryotherwise
details={'name':'phanindra','age':23,'area':'manuguru'}
print(details.get('name'))
print(details.get('percentage'))
print(details.get('percentage',85))
# Out:
# phanindra
# None
# 85

# %%
## updating or adding items to dictionary
details={'name':'phanindra','age':23,'area':'manuguru','percentage':80}
marks={'python':90,'soft skills':80,'aptitude':75,'percenatge':90}
details.update(marks)
print(details)
print(marks)
# Out:
# {'name': 'phanindra', 'age': 23, 'area': 'manuguru', 'percentage': 80, 'python': 90, 'soft skills': 80, 'aptitude': 75, 'percenatge': 90}
# {'python': 90, 'soft skills': 80, 'aptitude': 75, 'percenatge': 90}

# %%
## dictionaries not allows duplicates
details={'name':'phanindra','age':23,'area':'manuguru','percentage':80,'percentage':80,'percentage':72}
print(details)
# Out:
# {'name': 'phanindra', 'age': 23, 'area': 'manuguru', 'percentage': 72}

# %%
##get dictionary keys,values,and items
#keys() - it returns list of all dictionary keys
#values() -it returns list of all dictionary values
#items() - it returns list of all items in the dictionary
details={'name':'phanindra','age':23,'area':'manuguru','percentage':80}
print(details.keys())
print(details.values())
print(details.items())
print(list(details.keys()))
print(list(details.values()))
print(list(details.items()))
# Out:
# dict_keys(['name', 'age', 'area', 'percentage'])
# dict_values(['phanindra', 23, 'manuguru', 80])
# dict_items([('name', 'phanindra'), ('age', 23), ('area', 'manuguru'), ('percentage', 80)])
# ['name', 'age', 'area', 'percentage']
# ['phanindra', 23, 'manuguru', 80]
# [('name', 'phanindra'), ('age', 23), ('area', 'manuguru'), ('percentage', 80)]

# %%
# deleting items from dictiionary
#pop(key) - it returns value and removes the specified key item from dictionary
## pop(item) - it return and remove the last item from dictionary
details={'name':'phanindra','age':23,'area':'manuguru','percentage':80}
poped_value =details.pop('age')
print(poped_value)
print(details)
poped_value =details.pop('age',None)
print(details)
##pop item(deleting last from dict)
item=details.popitem()
print(details)
# Out:
# 23
# {'name': 'phanindra', 'area': 'manuguru', 'percentage': 80}
# {'name': 'phanindra', 'area': 'manuguru', 'percentage': 80}
# {'name': 'phanindra', 'area': 'manuguru'}

# %%
details={'name':'phanindra','age':23,'area':'manuguru','percentage':80,'percentage':80,'percentage':100}
print(len(details))
print(details.values())
print(details.keys())
# Out:
# 4
# dict_values(['phanindra', 23, 'manuguru', 100])
# dict_keys(['name', 'age', 'area', 'percentage'])

# %%
##iterate dictionary item
details={'name':'phanindra','age':23,'area':'manuguru','percentage':80,'percentage':80,'percentage':100}
for item in details.items():
    print (f"{item[0]}:{item[1]}")
# Out:
# name:phanindra
# age:23
# area:manuguru
# percentage:100

# %%
details={'name':'phanindra','age':23,'area':'manuguru','percentage':80}
print(details.items())
for key,value in details.items():
    print(f"{key}:{value}")
# Out:
# dict_items([('name', 'phanindra'), ('age', 23), ('area', 'manuguru'), ('percentage', 80)])
# name:phanindra
# age:23
# area:manuguru
# percentage:80

# %%
## membership checking
details={'name':'phanindra','age':23,'area':'manuguru','percentage':80}
if 'name' in details:
    print("key is present")
else:
    print("key is not present")
# Out:
# key is present

# %%
# Creating Contact Book
phn_book = {}


# Add Contact
def add_contact(name: str, number: str):
    if name not in phn_book:
        phn_book[name] = number
        print("Contact saved.")
    else:
        print("Contact already exists.")


# Update Contact
def update_contact(name: str, number: str):
    if name in phn_book:
        phn_book[name] = number
        print("Mobile number updated.")
    else:
        print("Contact not found.")


# Delete Contact
def delete_contact(name: str):
    if name in phn_book:
        phn_book.pop(name)
        print("Contact deleted successfully.")
    else:
        print("Contact not found.")


# Get Contact
def get_contact(name: str):
    number = phn_book.get(name)
    if number:
        print(f"{name} : {number}")
    else:
        print("Contact not found.")


# Display All Contacts
def all_contacts():
    if not phn_book:
        print("No contacts found.")
        return

    print("\n----- Contact List -----")
    for name, number in phn_book.items():
        print(f"{name} : {number}")

if __name__ == "__main__":

    while True:
        print("\n===== Contact Book =====")
        print("1. Add Contact")
        print("2. Update Contact")
        print("3. Delete Contact")
        print("4. Search Contact")
        print("5. Show All Contacts")
        print("6. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            name = input("Enter name: ")
            number = input("Enter mobile number: ")
            add_contact(name, number)

        elif choice == "2":
            name = input("Enter name: ")
            number = input("Enter new mobile number: ")
            update_contact(name, number)

        elif choice == "3":
            name = input("Enter name: ")
            delete_contact(name)

        elif choice == "4":
            name = input("Enter name: ")
            get_contact(name)

        elif choice == "5":
            all_contacts()

        elif choice == "6":
            print("Thank you for using Contact Book.")
            break

        else:
            print("Invalid choice. Try again.")
# Out:
# ===== Contact Book =====
# 1. Add Contact
# 2. Update Contact
# 3. Delete Contact
# 4. Search Contact
# 5. Show All Contacts
# 6. Exit
# Enter your choice:  6
# Thank you for using Contact Book.

# %%
##creating contact book
phn_book={}

def add_contact(name,number):
    if name not in phn_book:
        phn_book[name]=number
        print("name added successfully")
    else:
        print("name already exists")

## updating contact book

def update_contact(name,number):
    if name in phn_book:
        phn_book[name]=number
        print("name updated successfully")
    else:
        print("name not found")

## deleting name from contact book
def delete_contact(name):
    if name in phn_book:
        phn_book.pop(name)
        print("name deleted successfully")
    else:
        print("name connot found")

##get name from contact book
def get_contact(name):
    number=phn_book.get(name)
    if number:
        print(f"{name}:{number}")
    else:
        print("name doesn't found")

## display all contacts
def all_contacts():
    if not phn_book:
        print("no contacts found")
        return

    print("\n-----conatct list-----")
    for name ,number in phn_book.items():
        print(f"{name}:{number}")


if __name__ == "__main__":
    while True:
        print("\n=====contact list=====")
        print("1.Add contact")
        print("2.Update contact")
        print("3.Delete contact")
        print("4.Get contact")
        print("5.Display all contacts")
        print("6.Exit")

        choice=input("enter choice to fetch:")

        if choice == "1":
            name=input("enter your name")
            number=input("enter mobile number")
            add_contact(name,number)

        elif choice == "2":
            name=input("enter your name")
            number=input("enter mobile number")
            update_contact(name,number)

        elif choice == "3":
            name=input("enter your name")
            delete_contact(name)

        elif choice == "4":
            name=input("enter name")
            get_contact(name)

        elif choice == "5":
            all_contacts()


        elif choice == "6":
            print("Thank you for using contact book")
            break

        else:
            print("Invalid choice. Try again")
# Out:
# =====contact list=====
# 1.Add contact
# 2.Update contact
# 3.Delete contact
# 4.Get contact
# 5.Display all contacts
# 6.Exit
# enter choice to fetch: 6
# Thank you for using contact book
